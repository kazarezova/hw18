# %% [markdown]
# # classwork

# %%
N = 20

x = np.linspace(-5, 5, N)
y = 3*x - 1 + np.random.normal(scale=10, size=N)

X = np.column_stack([
    x**i for i in range(N)
])

model = LinearRegression(fit_intercept=False)
model.fit(X, y)
print(model.score(X, y))

print(model.coef_)
print(model.intercept_)

y_pred = model.predict(X)

sns.scatterplot(x=x, y=y)
sns.lineplot(x=x, y=y_pred)
plt.ylim([-10, 10])

# %% [markdown]
# # 2
# Рассмотрим следующую зависимость 𝑦=𝑦(𝑥): 𝑦=𝑏0+𝑎1sin(𝑥)+𝑏1cos(𝑥)+...+𝑎𝑚sin(𝑚𝑥)+𝑏𝑚cos(𝑚𝑥)
#
# Восстановить коэффициенты зависимости 𝑎1,...,𝑎𝑚,𝑏0,...,𝑏𝑚 для данных из файла sgn.csv для 𝑚= 1,5,20,100,1000 и визуализировать результат (точки и кривая).

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV

import math

# %%
df = pd.read_csv("sgn.csv")

x = df['x'].to_numpy()
y = df['y'].to_numpy()

m=1
 
X=[]
for each in x:
    new_row=[]
    for i in range(1,m+1):
        new_row.append(math.sin(each*i))
        new_row.append(math.cos(each*i))
    X.append(new_row)
X=pd.DataFrame(X).to_numpy()

model = LinearRegression()
model.fit(X, y)
print('score:',model.score(X, y))

print('coef:',model.coef_)
print('intercept:',model.intercept_)

y_pred = model.predict(X)

sns.scatterplot(x=x, y=y)
sns.lineplot(x=x, y=y_pred)
# Out:
# score: 0.7978249569512397
# coef: [1.26491679 0.00151386]
# intercept: -0.004451120260183471

# %%
df = pd.read_csv("sgn.csv")

x = df['x'].to_numpy()
y = df['y'].to_numpy()

m=5
 
X=[]
for each in x:
    new_row=[]
    for i in range(1,m+1):
        new_row.append(math.sin(each*i))
        new_row.append(math.cos(each*i))
    X.append(new_row)
X=pd.DataFrame(X).to_numpy()

model = LinearRegression()
model.fit(X, y)
print('score:',model.score(X, y))

print('coef:',model.coef_)
print('intercept:',model.intercept_)

y_pred = model.predict(X)

sns.scatterplot(x=x, y=y)
sns.lineplot(x=x, y=y_pred)
# Out:
# score: 0.9209831078750252
# coef: [ 1.26491679e+00  1.52479113e-03  2.62664126e-04  1.21762323e-03
#   4.25026998e-01 -6.29953476e-03 -3.80589168e-03 -3.55555065e-03
#   2.57432965e-01 -1.51714195e-03]
# intercept: -0.004456588073839763

# %%
df = pd.read_csv("sgn.csv")

x = df['x'].to_numpy()
y = df['y'].to_numpy()

m=20
 
X=[]
for each in x:
    new_row=[]
    for i in range(1,m+1):
        new_row.append(math.sin(each*i))
        new_row.append(math.cos(each*i))
    X.append(new_row)
X=pd.DataFrame(X).to_numpy()

model = LinearRegression()
model.fit(X, y)
print('score:',model.score(X, y))

print('coef:',model.coef_)
print('intercept:',model.intercept_)

y_pred = model.predict(X)

sns.scatterplot(x=x, y=y)
sns.lineplot(x=x, y=y_pred)
# Out:
# score: 0.9703655633826609
# coef: [ 1.26491679e+00  1.52663033e-03  2.62664126e-04  1.21578403e-03
#   4.25026998e-01 -6.29769556e-03 -3.80589168e-03 -3.55738985e-03
#   2.57432965e-01 -1.51530275e-03  2.58057807e-03  5.57797926e-03
#   1.89023306e-01 -3.13974590e-03 -1.67366696e-03 -3.12161190e-03
#   1.40173314e-01 -2.09761782e-03  1.75548209e-03 -7.39087045e-03
#   1.22313698e-01 -6.79173393e-03 -5.76361021e-03 -4.52414003e-03
#   1.00734791e-01  2.24983005e-03 -5.63318179e-03 -2.60330039e-05
#   8.44272410e-02  5.07302425e-04  6.99321870e-03 -3.57746705e-04
#   7.45034555e-02  4.43675181e-03  2.73854030e-03 -1.79474500e-03
#   7.41500351e-02 -4.08391886e-03  1.78243134e-03  3.64683060e-03]
# intercept: -0.004457507672851473

# %%
df = pd.read_csv("sgn.csv")

x = df['x'].to_numpy()
y = df['y'].to_numpy()

m=100
 
X=[]
for each in x:
    new_row=[]
    for i in range(1,m+1):
        new_row.append(math.sin(each*i))
        new_row.append(math.cos(each*i))
    X.append(new_row)
X=pd.DataFrame(X).to_numpy()

model = LinearRegression()
model.fit(X, y)
print('score:',model.score(X, y))

print('coef:',model.coef_)
print('intercept:',model.intercept_)

y_pred = model.predict(X)

sns.scatterplot(x=x, y=y)
sns.lineplot(x=x, y=y_pred)
# Out:
# score: 0.9874294921996635
# coef: [ 1.26491679e+00  1.57323039e-03  2.62664126e-04  1.16918397e-03
#   4.25026998e-01 -6.25109551e-03 -3.80589168e-03 -3.60398991e-03
#   2.57432965e-01 -1.46870270e-03  2.58057807e-03  5.53137921e-03
#   1.89023306e-01 -3.09314584e-03 -1.67366696e-03 -3.16821196e-03
#   1.40173314e-01 -2.05101777e-03  1.75548209e-03 -7.43747050e-03
#   1.22313698e-01 -6.74513388e-03 -5.76361021e-03 -4.57074008e-03
#   1.00734791e-01  2.29643010e-03 -5.63318179e-03 -7.26330584e-05
#   8.44272410e-02  5.53902480e-04  6.99321870e-03 -4.04346759e-04
#   7.45034555e-02  4.48335186e-03  2.73854030e-03 -1.84134505e-03
#   7.41500351e-02 -4.03731881e-03  1.78243134e-03  3.60023054e-03
#   5.97305614e-02 -3.68012029e-03 -7.33635872e-04  5.29226718e-03
#   5.42002192e-02  3.42270945e-04  8.48652976e-04  2.58111551e-03
#   5.38799453e-02 -5.22659628e-04 -5.41591004e-03 -6.24148511e-03
#   4.78979239e-02 -2.43771021e-03 -7.44505683e-03  1.46995974e-03
# ...

# %%
df = pd.read_csv("sgn.csv")

x = df['x'].to_numpy()
y = df['y'].to_numpy()

m=1000
 
X=[]
for each in x:
    new_row=[]
    for i in range(1,m+1):
        new_row.append(math.sin(each*i))
        new_row.append(math.cos(each*i))
    X.append(new_row)
X=pd.DataFrame(X).to_numpy()

model = LinearRegression()
model.fit(X, y)
print('score:',model.score(X, y))

print('coef: too many of them') #model.coef_
print('intercept:',model.intercept_)

y_pred = model.predict(X)

sns.scatterplot(x=x, y=y)
sns.lineplot(x=x, y=y_pred)
# Out:
# score: 0.9999998786305092
# coef: too many of them
# intercept: -0.005715547664564798

# %% [markdown]
# # 3
# Решить прошлую задачу при 𝑚=1000, используя LassoCV вместо LinearRegression. Визуализировать и интерпретировать результат.

# %%
df = pd.read_csv("sgn.csv")

x = df['x'].to_numpy()
y = df['y'].to_numpy()

m=1000
 
X=[]
for each in x:
    new_row=[]
    for i in range(1,m+1):
        new_row.append(math.sin(each*i))
        new_row.append(math.cos(each*i))
    X.append(new_row)
X=pd.DataFrame(X).to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=17)

model = LassoCV(positive=True)
model.fit(X_train, y_train)

print('train score:',model.score(X_train, y_train))
print('test score:',model.score(X_test, y_test))

print('coef: too many of them') #model.coef_
print('intercept:',model.intercept_)

y_pred = model.predict(X)

sns.scatterplot(x=x, y=y)
sns.lineplot(x=x, y=y_pred)
# Out:
# train score: 0.9895828466899741
# test score: 0.9752107965238506
# coef: too many of them
# intercept: -0.007216924975486261

# %% [markdown]
# # 4
# Рассмотрим задачу бинарной классификации luminal A vs luminal B и три классификатора:
#
# 1) линейный SVM (class_weight="balanced");
#
# 2) линейный SVM, построенный на топ-2 признаках(относительно модулей весов);
#
# 3) логистическая регрессия с параметрамиclass_weight="balanced C=0.01, penalty="l1 solver="liblinear":при использовании train_test_split с random_state=17 методвыдаст два ненулевых коэффициента.
#
# Сравнить качество классификации (сбалансированная точность), используя train_test_split с stratify=y и random_state=17.

# %% [markdown]
# # 5
# Оценить вероятность того, что выборка размера 𝑁=20 из двумерного нормального распределения (loc=0), разбитого на два класса по 10 элементов, линейно разделима. Для решения задачи воспользоваться методом Монте-Карло: 𝑀= 10000 раз сгенерировать набор данных, найти долю случаев, при которых логистическая регрессия выдает точность 1 (необходимо отключить регуляризацию: penalty="none"). Для воспроизводимости кодаиспользовать np.random.seed(17).
